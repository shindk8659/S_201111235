# %%
# %%writefile src/ds_web_crawl_pythonorgURL.py
# coding: utf-8
    
import requests
import re
rResponse = requests.get('http://python.org/')
_html = rResponse.text
print len(_html)

print type(_html)

import re

p=re.compile('href="(http://.*?)"')
nodes=p.findall(_html)
print "http url은 몇 개?",len(nodes)
for i, node in enumerate(nodes):
    print i, node
    
    
import re
p=re.compile('<h1>(.*?)</h1>')
h1tags=p.findall(_html)
for tag in h1tags:
    print tag
    
import re
p=re.compile('<p>(.*?)</p>')
ptags=p.findall(_html)

print len(ptags)
print ptags[0]

from urllib import urlopen
from bs4 import BeautifulSoup
#_html = urlopen("http://en.wikipedia.org/wiki/Kevin_Bacon")
_html = urlopen("http://en.wikipedia.org/wiki/HTML").read()
tree = BeautifulSoup(_html, "lxml")
counter=0
for link in tree.findAll("a"):
    if 'href' in link.attrs:
        if counter<20:
            print counter, link.attrs['href']
        counter+=1
print "Total: ", counter
    
    
    
print type(_html)
print len(_html)

from lxml import etree
_htmlTree = etree.HTML(_html)
result = etree.tostring(_htmlTree, pretty_print=True, method="html")
print len(result)
nodes = _htmlTree.xpath('//*[@href]')
print len(nodes)
for i, node in enumerate(nodes):
    if i<20:
        print i, node.attrib
        
        

                        
import lxml.html
from lxml.cssselect import CSSSelector
import requests
r = requests.get('http://python.org/')

html = lxml.html.fromstring(r.text)
sel=CSSSelector('a[href]')
# Apply the selector to the DOM tree.
nodes = sel(html)
print len(nodes)
for i,node in enumerate(nodes):
    #print lxml.html.tostring(item)
    if i<20:
        print i, node.get('href'), node.text
                        
                        
                        
import lxml.html
from lxml.cssselect import CSSSelector
import requests
r = requests.get('http://python.org/')

html = lxml.html.fromstring(r.text)
sel=CSSSelector('a[href]')
nodes = sel(html)
for node in nodes:
    print node.text
    print "----------"
# Out:
# Overwriting src/ds_web_crawl_pythonorgURL.py

# %%
# !python src/ds_web_crawl_pythonorgURL.py
# Out:
# 47454
# <type 'unicode'>
# http url은 몇 개? 44
# 0 http://www.ie6countdown.com/
# 1 http://browsehappy.com/
# 2 http://www.google.com/chromeframe/?redirect=true
# 3 http://plus.google.com/+Python
# 4 http://www.facebook.com/pythonlang?fref=ts
# 5 http://twitter.com/ThePSF
# 6 http://brochure.getpython.info/
# 7 http://wiki.python.org/moin/Languages
# 8 http://python.org/dev/peps/
# 9 http://planetpython.org/
# 10 http://pyfound.blogspot.com/
# 11 http://pycon.blogspot.com/
# 12 http://docs.python.org/3/tutorial/introduction.html#using-python-as-a-calculator
# 13 http://blog.python.org
# 14 http://feedproxy.google.com/~r/PythonInsider/~3/C-xfWJKP0-A/python-361-is-now-available.html
# 15 http://feedproxy.google.com/~r/PythonInsider/~3/w2AW2NRSOEM/python-361rc1-is-now-available-for.html
# 16 http://feedproxy.google.com/~r/PythonInsider/~3/NeIHRAidlpc/python-353-and-346-are-now-available.html
# 17 http://feedproxy.google.com/~r/PythonInsider/~3/UoiMThSwgQM/python-353rc1-and-python-346rc1-are-now.html
# 18 http://feedproxy.google.com/~r/PythonInsider/~3/4gOtq8ChYHk/python-360-is-now-available.html
# 19 http://www.djangoproject.com/
# 20 http://www.pylonsproject.org/
# 21 http://bottlepy.org
# 22 http://tornadoweb.org
# 23 http://flask.pocoo.org/
# 24 http://www.web2py.com/
# 25 http://wiki.python.org/moin/TkInter
# 26 http://www.riverbankcomputing.co.uk/software/pyqt/intro
# 27 http://www.wxpython.org/
# 28 http://www.scipy.org
# 29 http://pandas.pydata.org/
# 30 http://ipython.org
# 31 http://buildbot.net/
# 32 http://trac.edgewall.org/
# 33 http://roundup.sourceforge.net/
# 34 http://www.ansible.com
# 35 http://www.saltstack.com
# 36 http://brochure.getpython.info/
# 37 http://wiki.python.org/moin/Languages
# 38 http://python.org/dev/peps/
# 39 http://planetpython.org/
# 40 http://pyfound.blogspot.com/
# 41 http://pycon.blogspot.com/
# 42 http://docs.python.org/devguide/
# 43 http://bugs.python.org/
# Functions Defined
# Compound Data Types
# Intuitive Interpretation
# Quick &amp; Easy to Learn
# All the Flow You&rsquo;d Expect
# 18
# <strong>Notice:</strong> While Javascript is not essential for this website, your interaction with the content will be limited. Please turn Javascript on for the full experience.
# 0 /wiki/Wikipedia:Protection_policy#semi
# 1 #mw-head
# 2 #p-search
# 3 /wiki/HTM_(disambiguation)
# 4 /wiki/Help:HTML_in_wikitext
# 5 /wiki/File:HTML.svg
# 6 /wiki/Filename_extension
# 7 /wiki/Media_type
# 8 /wiki/Type_code
# 9 /wiki/World_Wide_Web_Consortium
# 10 /wiki/WHATWG
# 11 /wiki/Software_release_life_cycle
# 12 /wiki/HTML5
# 13 /wiki/Document_file_format
# 14 /wiki/Standard_Generalized_Markup_Language
# 15 /wiki/XHTML
# 16 /wiki/International_standard
# 17 http://www.w3.org/TR/html/
# 18 http://whatwg.org/html
# 19 http://www.w3.org/TR/html51/
# Total:  1610
# <type 'str'>
# 319070
# 322833
# 1621
# 0 {'href': '/w/load.php?debug=false&lang=en&modules=ext.cite.styles%7Cext.pygments%2CwikimediaBadges%7Cext.uls.interlanguage%7Cext.visualEditor.desktopArticleTarget.noscript%7Cmediawiki.legacy.commonPrint%2Cshared%7Cmediawiki.sectionAnchor%7Cmediawiki.skinning.interface%7Cskins.vector.styles%7Cwikibase.client.init&only=styles&skin=vector', 'rel': 'stylesheet'}
# 1 {'href': '/w/load.php?debug=false&lang=en&modules=site.styles&only=styles&skin=vector', 'rel': 'stylesheet'}
# 2 {'href': 'android-app://org.wikipedia/http/en.m.wikipedia.org/wiki/HTML', 'rel': 'alternate'}
# 3 {'href': '/static/apple-touch/wikipedia.png', 'rel': 'apple-touch-icon'}
# 4 {'href': '/static/favicon/wikipedia.ico', 'rel': 'shortcut icon'}
# 5 {'href': '/w/opensearch_desc.php', 'type': 'application/opensearchdescription+xml', 'rel': 'search', 'title': 'Wikipedia (en)'}
# 6 {'href': '//en.wikipedia.org/w/api.php?action=rsd', 'type': 'application/rsd+xml', 'rel': 'EditURI'}
# 7 {'href': '//creativecommons.org/licenses/by-sa/3.0/', 'rel': 'copyright'}
# 8 {'href': 'https://en.wikipedia.org/wiki/HTML', 'rel': 'canonical'}
# 9 {'href': '//login.wikimedia.org', 'rel': 'dns-prefetch'}
# 10 {'href': '//meta.wikimedia.org', 'rel': 'dns-prefetch'}
# 11 {'href': '/wiki/Wikipedia:Protection_policy#semi', 'title': 'This article is semi-protected due to vandalism'}
# 12 {'href': '#mw-head'}
# 13 {'href': '#p-search'}
# 14 {'href': '/wiki/HTM_(disambiguation)', 'class': 'mw-redirect mw-disambig', 'title': 'HTM (disambiguation)'}
# 15 {'href': '/wiki/Help:HTML_in_wikitext', 'title': 'Help:HTML in wikitext'}
# 16 {'href': '/wiki/File:HTML.svg', 'class': 'image'}
# 17 {'href': '/wiki/Filename_extension', 'title': 'Filename extension'}
# 18 {'href': '/wiki/Media_type', 'title': 'Media type'}
# 19 {'href': '/wiki/Type_code', 'title': 'Type code'}
# 197
# 0 #content Skip to content
# 1 #python-network
#
# 2 / Python
# 3 /psf-landing/ PSF
# 4 https://docs.python.org Docs
# 5 https://pypi.python.org/ PyPI
# 6 /jobs/ Jobs
# 7 /community/ Community
# 8 #top
#
# 9 / None
# 10 #site-map None
# 11 # None
# 12 javascript:; Smaller
# 13 javascript:; Larger
# 14 javascript:; Reset
# 15 # Socialize
# 16 http://plus.google.com/+Python None
# 17 http://www.facebook.com/pythonlang?fref=ts None
# 18 http://twitter.com/ThePSF None
# 19 /community/irc/ None
# Skip to content
# ----------
#
#
# ----------
# Python
# ----------
# PSF
# ----------
# Docs
# ----------
# PyPI
# ----------
# Jobs
# ----------
# Community
# ----------
#
#
# ----------
# None
# ----------
# None
# ----------
# None
# ----------
# Smaller
# ----------
# Larger
# ----------
# Reset
# ----------
# Socialize
# ----------
# None
# ----------
# None
# ----------
# None
# ----------
# None
# ----------
# Sign In
# ----------
# Sign Up / Register
# ----------
# Sign In
# ----------
# About
# ----------
# Applications
# ----------
# Quotes
# ----------
# Getting Started
# ----------
# Help
# ----------
# Python Brochure
# ----------
# Downloads
# ----------
# All releases
# ----------
# Source code
# ----------
# Windows
# ----------
# Mac OS X
# ----------
# Other Platforms
# ----------
# License
# ----------
# Alternative Implementations
# ----------
# Documentation
# ----------
# Docs
# ----------
# Audio/Visual Talks
# ----------
# Beginner's Guide
# ----------
# Developer's Guide
# ----------
# FAQ
# ----------
# Non-English Docs
# ----------
# PEP Index
# ----------
# Python Books
# ----------
# Community
# ----------
# Diversity
# ----------
# IRC
# ----------
# Mailing Lists
# ----------
# Python Conferences
# ----------
# Special Interest Groups
# ----------
# Python Wiki
# ----------
# Python Logo
# ----------
# Merchandise
# ----------
# Community Awards
# ----------
# Success Stories
# ----------
# Arts
# ----------
# Business
# ----------
# Education
# ----------
# Engineering
# ----------
# Government
# ----------
# Scientific
# ----------
# Software Development
# ----------
# News
# ----------
# Python News
# ----------
# Community News
# ----------
# PSF News
# ----------
# PyCon News
# ----------
# Events
# ----------
# Python Events
# ----------
# User Group Events
# ----------
# Python Events Archive
# ----------
# User Group Events Archive
# ----------
# Submit an Event
# ----------
# >_
#
# ----------
# More about defining functions in Python 3
# ----------
# More about lists in Python 3
# ----------
# More about simple math functions in Python 3
# ----------
# Whet your appetite
# ----------
# More control flow tools in Python 3
# ----------
# Learn More
# ----------
# Start with our Beginner’s Guide
# ----------
# Check here
# ----------
# Python 3.6.1
# ----------
# Python 2.7.13
# ----------
# docs.python.org
# ----------
# jobs.python.org
# ----------
# More
# ----------
# Python 3.6.1 is now available.   Python 3.6.1 is the ...
# ----------
# Python 3.6.1rc1 is now available.   Python 3.6.1rc1 is the ...
# ----------
# Python 3.5.3 and Python 3.4.6 are now available for download. ...
# ----------
# Python 3.5.3rc1 and Python 3.4.6rc1 are now available for download. ...
# ----------
# Python 3.6.0 is now available!   Python 3.6.0 is the ...
# ----------
# More
# ----------
# PyData Amsterdam 2017
# ----------
# PythonCamp 2017
# ----------
# Django Girls Bucaramanga, Colombia
# ----------
# PyCon UA 2017
# ----------
# Python Meetup Innsbruck: imp.reload(innsbruck)
# ----------
# More
# ----------
# ILM runs a batch processing environment capable of modeling, rendering and compositing tens of thousands of motion picture frames per day. Thousands of machines running Linux, IRIX, Compaq Tru64, OS X, Solaris, and Windows join together to provide a production pipeline used by ~800 users daily. Speed of development is key, and Python was a faster way to code (and re-code) the programs that control this production pipeline.
# ----------
# Industrial Light & Magic Runs on Python
# ----------
# More
# ----------
# Django
# ----------
# Pyramid
# ----------
# Bottle
# ----------
# Tornado
# ----------
# Flask
# ----------
# web2py
# ----------
# tkInter
# ----------
# PyGObject
# ----------
# PyQt
# ----------
# PySide
# ----------
# Kivy
# ----------
# wxPython
# ----------
# SciPy
# ----------
# Pandas
# ----------
# IPython
# ----------
# Buildbot
# ----------
# Trac
# ----------
# Roundup
# ----------
# Ansible
# ----------
# Salt
# ----------
# OpenStack
# ----------
# Python Enhancement Proposals
# ----------
# None
# ----------
# Python Software Foundation
# ----------
# Learn more
# ----------
# Become a Member
# ----------
# Donate to the PSF
# ----------
# None
# ----------
# About
# ----------
# Applications
# ----------
# Quotes
# ----------
# Getting Started
# ----------
# Help
# ----------
# Python Brochure
# ----------
# Downloads
# ----------
# All releases
# ----------
# Source code
# ----------
# Windows
# ----------
# Mac OS X
# ----------
# Other Platforms
# ----------
# License
# ----------
# Alternative Implementations
# ----------
# Documentation
# ----------
# Docs
# ----------
# Audio/Visual Talks
# ----------
# Beginner's Guide
# ----------
# Developer's Guide
# ----------
# FAQ
# ----------
# Non-English Docs
# ----------
# PEP Index
# ----------
# Python Books
# ----------
# Community
# ----------
# Diversity
# ----------
# IRC
# ----------
# Mailing Lists
# ----------
# Python Conferences
# ----------
# Special Interest Groups
# ----------
# Python Wiki
# ----------
# Python Logo
# ----------
# Merchandise
# ----------
# Community Awards
# ----------
# Success Stories
# ----------
# Arts
# ----------
# Business
# ----------
# Education
# ----------
# Engineering
# ----------
# Government
# ----------
# Scientific
# ----------
# Software Development
# ----------
# News
# ----------
# Python News
# ----------
# Community News
# ----------
# PSF News
# ----------
# PyCon News
# ----------
# Events
# ----------
# Python Events
# ----------
# User Group Events
# ----------
# Python Events Archive
# ----------
# User Group Events Archive
# ----------
# Submit an Event
# ----------
# Contributing
# ----------
# Developer's Guide
# ----------
# Issue Tracker
# ----------
# python-dev list
# ----------
# Core Mentorship
# ----------
# None
# ----------
# Help &
# ----------
# Diversity
# ----------
# Submit Website Bug
# ----------
# Status
# ----------
# Python Software Foundation
# ----------
# Legal Statements
# ----------
# Privacy Policy
# ----------
